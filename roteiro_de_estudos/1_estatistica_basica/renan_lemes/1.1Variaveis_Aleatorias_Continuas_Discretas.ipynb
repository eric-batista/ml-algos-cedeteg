# %% [markdown]
# # Variáveis Aleatórias Contínuas e Discretas.
#
# ## Teórico:
# ---
# Uma variavel aleatória quantitativa depende de valores aleatório, vamos dar um exemplo um laçamento de um dado que pode dar qualquer número de 1 a 6 embora sabendo os possiveis resultados,
# assim podemos separar as variáveis em aleatória discretas, continuas ou mistas.
# *  Discreta:
#     Ela pode assumir valores que podem ser "contados" ou seja, uma variável aleátoria discreta é uma variável para qual o conjunto A é um finito ou infinitopor exempplo o conjuto. <p>$$ A = {1,2,3,4,5,6, ...} $$</p>
#     * Vamos dar um exemplo mais pratico como o lançamento de uma moeda.
#         Uma variável aleatória  pode ser usada para descrever os possíveis resultados do lançamento de uma moeda, os possíveis resultados para um lançamento podem ser descrito por
#         um espaço amostral como:<p>$$ Y(x) = \begin{cases}&\text{ 1, se }x = cara\\&\text{ 0, se }x = coroa\end{cases}$$</p>
# * Continuas:
#     Uma variável aleatória continua pode assumir qualquer valor numérico em um certo intervalo ou séries de intervalos, ou seja uma variável aleatória continua é uma variável com o qual
#     o conjunto A é um conjunto infinito não enumerável.
#     Exemplo, seja um relógio é uma variável aleatória discreta e que assumimos suas possiveis horas minutos e segundos por um intervalo como $[0,360) = {X \in {R} : 0 \le X < 360}$.
# * Mista:
#     Nesta situação temos como também como nossas variáveis podem assumir tanto como valores discretos como continuas no caso a chamamos de variável mista.
#     Um exemplo que podemos dar é uma moeda é lançada e uma roleta é girada, ou seja se cair cara é igual ao valor da roleta se o resultado cair coroa então o valor vai ser igual a -1.

# %% [markdown]
# # Prática.
# ---
# ## Vamos analisar tanto como variáveis continuas, discretas e mistas.
# Tudo vai ser desenvolvido em python e analisaremos suas diferenças e tais como:

# %%
## importando as blibliotecas ##
import random as rd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = rd.randint(1,6) 
y = rd.randint(1,6) 
z = rd.randint(1,6) 
h = rd.randint(1,6) 
j = rd.randint(1,6) 

df_discreta = [x,y,z,h,j]
df_discreta 

## ou seja aqui ele temos uma pequena lista de números aleatórios e inteiros ou seja Variáveis Discretas simulando a jogada de 5 vezes um dado##
# Out:
# [5, 2, 5, 1, 2]

# %%
x = rd.randint(0,580) /100
y = rd.randint(0,580) /100
z = rd.randint(0,580) /100
h = rd.randint(0,580) /100
j = rd.randint(0,580) /100

df_discreta = [x,y,z,h,j]
df_discreta 

## Já aqui temos uma pequena lista porem com Váriaveis Continuas como kg , mg , ou altura de uma pessoa no caso se basea por um intervalo ou até mesmo porcentagem. ##
# Out:
# [1.59, 0.9, 1.21, 3.87, 0.22]

# %%
## vamos agora simular uma pessoa girando uma roleta de 0 a 360 possibilidades de o evento acontecer ela vai girar 5 vezes  ##
df =  pd.DataFrame
a = rd.randint(0,360)
b = rd.randint(0,360)
c = rd.randint(0,360)
d = rd.randint(0,360)
e = rd.randint(0,360)
n_de_tentativas = [1,2,3,4,5]
tentativas = [a,b,c,d,e]
df = n_de_tentativas,tentativas
df = pd.DataFrame(df)
df = df.T
df.plot(x=0,y=1)
plt.ylabel('Angulos')
plt.xlabel('Tentativas')
plt.show()

# %% [markdown]
# # Conclusão:
# Análisando as variáveis tanto como continuas ou discretas podemos definir tratamentos especificos pra tais dados.
# * Exemplo:
# Análisando o mercado finaceiro, temos tantos como variáveis relacionadas como data e outras como preço ou seja
# data como continua e preço como discreta porem dependendo da "moeda".

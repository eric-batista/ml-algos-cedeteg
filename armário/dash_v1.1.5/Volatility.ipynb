# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as pdr
import datetime
import math

# %%
def get(tickers, startdata, enddate):
    def data(ticker):
        return pdr.get_data_yahoo(ticker, start=startdata, end=enddate)
    datas = map (data,tickers) 
    return (pd.concat(datas, keys=tickers, names=['Ticker', 'Date']))

# %%
tickers = ['ENGI11.SA']
data = get(tickers, datetime.datetime(2010,1,1), datetime.datetime(2020,1,1))

# %%
data
# Out:
#                            High        Low       Open      Close    Volume  \
# Ticker    Date
# ENGI11.SA 2010-01-04   9.360198   9.360198   9.360198   9.360198       0.0
#           2010-01-05   9.540202   9.000191   9.360198   9.495201    1999.0
#           2010-01-06   9.495201   9.405199   9.495201   9.405199    3888.0
#           2010-01-07   9.522202   9.522202   9.522202   9.522202     555.0
#           2010-01-08   9.495201   9.360198   9.495201   9.360198    4444.0
# ...                         ...        ...        ...        ...       ...
#           2019-12-20  52.430000  51.750000  52.430000  51.880001  349300.0
#           2019-12-23  51.919998  51.290001  51.599998  51.529999  457100.0
#           2019-12-26  52.820000  51.959999  52.500000  52.770000  540900.0
#           2019-12-27  53.709999  52.619999  53.500000  53.099998  403600.0
#           2019-12-30  54.509998  53.340000  53.570000  54.240002  398500.0
#
#                       Adj Close
# Ticker    Date
# ENGI11.SA 2010-01-04   6.056388
#           2010-01-05   6.143740
#           2010-01-06   6.085505
#           2010-01-07   6.161210
#           2010-01-08   6.056388
# ...                         ...
#           2019-12-20  49.286942
#           2019-12-23  48.954426
#           2019-12-26  50.132458
#           2019-12-27  50.445961
#           2019-12-30  51.528984
#
# [2478 rows x 6 columns]

# %%
data_retorno_diario = np.log(data.Close.pct_change() +1)
data_retorno_diario.fillna(0, inplace = True)
data_retorno_diario.head()
# Out:
# Ticker     Date
# ENGI11.SA  2010-01-04    0.000000
#            2010-01-05    0.014320
#            2010-01-06   -0.009524
#            2010-01-07    0.012363
#            2010-01-08   -0.017160
# Name: Close, dtype: float64

# %%
def pct(data_close):
    data_pct = (data_close / data_close.shift(1) -1)
    data_pct.fillna(0, inplace=True)
    return data_pct

# %%
data['PCT'] = pct(data.Close)
data['PCT']
# Out:
# Ticker     Date
# ENGI11.SA  2010-01-04    0.000000
#            2010-01-05    0.014423
#            2010-01-06   -0.009479
#            2010-01-07    0.012440
#            2010-01-08   -0.017013
#                            ...
#            2019-12-20    0.000772
#            2019-12-23   -0.006746
#            2019-12-26    0.024064
#            2019-12-27    0.006254
#            2019-12-30    0.021469
# Name: PCT, Length: 2478, dtype: float64

# %%
def Volatilidade(data_pct):
    data_vola = data_pct.rolling(252).std() * np.sqrt(252)
    data_vola.fillna(0, inplace=True)
    return(data_vola)

# %%
data['Volatilidade'] = Volatilidade(data.PCT) * 100
data['Volatilidade']
# Out:
# Ticker     Date
# ENGI11.SA  2010-01-04     0.000000
#            2010-01-05     0.000000
#            2010-01-06     0.000000
#            2010-01-07     0.000000
#            2010-01-08     0.000000
#                            ...
#            2019-12-20    21.064281
#            2019-12-23    21.053954
#            2019-12-26    21.078384
#            2019-12-27    21.004185
#            2019-12-30    21.047089
# Name: Volatilidade, Length: 2478, dtype: float64

# %%
data['PCT'].plot(figsize=(28,12))
plt.show()

# %%
from web_scrapping import import_ind

df1, dff2 = import_ind('Vale3')
df1
# Out:
#              indicadores    2021    2020    2019     2018    2017     2016  \
# 0                     DY  19,30%   2,75%   2,65%    3,86%   3,29%    0,65%
# 1                     PL    4,28   17,30  -42,22    10,50   11,98    10,12
# 2              PEG_RATIO    0,00   -0,03       -     0,23    0,37    -0,08
# 3                   P_PV    1,87    2,49    1,74     1,58    1,47     1,06
# 4             EV_EBITIDA    2,66    6,34   15,85        -       -        -
# 5                EV_EBIT    3,11    9,03  139,25     7,11    7,85    10,44
# 6              P_EBITIDA    2,66    6,23   14,32        -       -        -
# 7                 P_EBIT    3,12    8,88  125,75     6,24    6,11     6,50
# 8                    VPA   40,61   35,16   30,56    32,25   27,41    24,26
# 9                P_ATIVO    0,81    0,97    0,76     0,79    0,64     0,42
# 10                   LPA   17,75    5,05   -1,26     4,86    3,36     2,54
# 11                  S_SR    1,32    2,22    1,89     2,00    1,95     1,42
# 12            P_CAP_GIRO    7,03    9,07   21,85    11,35   10,92     3,65
# 13      P_ATIVO_CIRC_LIQ   -1,09   -1,32   -0,94    -0,95   -0,80    -0,54
# 14        DIV_LIQUIDA_PL    0,01    0,04    0,19     0,22    0,42     0,64
# 15   DIV_LIQUIDA_EBITIDA    0,01    0,11    1,54        -       -        -
# 16      DIV_LIQUIDA_EBIT    0,01    0,15   13,49     0,87    1,74     3,94
# 17             PL_ATIVOS    0,43    0,39    0,44     0,50    0,44     0,39
# 18       PASSIVOS_ATIVOS    0,56    0,62    0,57     0,49    0,55     0,59
# 19          LIQ_CORRENTE    1,77    1,67    1,23     1,67    1,45     2,01
# 20               M_BRUTA  61,68%  52,73%  43,60%   39,62%  38,03%   35,39%
# 21             M_EBITIDA  49,81%  35,57%  13,24%       -%      -%       -%
# 22                M_EBIT  42,53%  24,97%   1,51%   32,10%  31,82%   21,89%
# 23             M_LIQUIDA  30,99%  12,81%  -4,49%   19,08%  16,24%   14,07%
# 24                   ROE  43,71%  14,38%  -4,13%   15,06%  12,26%   10,46%
# 25                   ROA  18,83%   5,59%  -1,80%    7,51%   5,37%    4,13%
# 26                  ROIC  35,12%  18,93%  -0,12%   18,07%  13,45%    4,86%
# 27           GIRO_ATIVOS    0,61    0,44    0,40     0,39    0,33     0,29
# 28  CAGR_RECEITAS_5_ANOS  21,72%  21,72%  12,46%    5,79%   3,53%   -1,21%
# 29    CAGR_LUCROS_5_ANOS      -%      -%      -%  194,87%  12,25%  -18,85%
#
#        2015     2014      2013    2012    2011    2010    2009    2008
# 0     7,49%    8,63%     5,06%   5,35%   7,31%       0       0       0
# 1     -1,55   123,17  1.664,73   22,93    5,60       0       0       0
# 2      0,00     0,17    -16,84   -0,31       -       0       0       0
# 3      0,52     0,80      1,29    1,51    1,48       0       0       0
# 4         -        -         -       -       -       0       0       0
# 5     -5,83     8,81      7,42   18,25    4,79       0       0       0
# 6         -        -         -       -       -       0       0       0
# 7     -2,39     5,64      5,73   14,96    4,04       0       0       0
# 8     25,01    27,29     27,65   27,93   26,74       0       0       0
# 9      0,20     0,38      0,66    0,85    0,89       0       0       0
# 10    -8,43     0,18      0,02    1,84    7,05       0       0       0
# 11     0,88     1,42      1,89    2,49    2,10       0       0       0
# 12     3,55     4,66      5,54   11,16   10,87       0       0       0
# 13    -0,24    -0,46     -0,82   -1,03   -1,07       0       0       0
# 14     0,75     0,45      0,38    0,33    0,27    0,27    0,30    0,22
# 15        -        -         -       -       -       -       -       -
# 16    -3,45     3,17      1,69    3,29    0,75    0,75    2,16    0,79
# 17     0,38     0,47      0,51    0,57    0,59    0,52    0,54    0,52
# 18     0,60     0,52      0,48    0,42    0,39    0,46    0,44    0,46
# 19     1,47     1,88      2,54    1,79    2,03    1,81    2,10    2,93
# 20   19,57%   34,92%    48,26%  45,40%  59,19%  59,44%  42,78%  54,42%
# 21       -%       -%        -%      -%      -%      -%      -%      -%
# 22  -36,67%   25,21%    32,95%  16,62%  52,09%  48,59%  27,56%  37,16%
# 23  -56,64%    1,16%     0,11%  10,84%  37,62%  36,13%  21,31%  30,17%
# 24  -33,71%    0,65%     0,08%   6,49%  26,36%  26,82%  10,79%  22,09%
# 25  -12,79%    0,31%     0,04%   3,71%  15,64%  14,01%   5,82%  11,46%
# 26  -19,03%    7,59%     8,23%   5,78%  22,70%  20,86%   5,91%  17,46%
# 27     0,23     0,27      0,35    0,34    0,42    0,39    0,27    0,38
# 28   -1,27%   11,24%     7,55%      -%      -%      -%      -%      -%
# 29       -%  -37,90%   -64,79%      -%      -%      -%      -%      -%

# %%
dff2
# Out:
#   patrimonio_liquido           ativos ativo_circulante    divida_bruta  \
# 0    208.436.906.000  483.789.293.000  127.068.007.000  69.343.450.000
#
#   disponibilidade divida_liquida valor_de_mercado   valor_de_firma  \
# 0  68.274.694.000  1.068.756.000  390.990.681.674  392.059.437.674
#
#   n_total_de_papeis segmento_de_listagem free_float
# 0     5.132.458.410         Novo Mercado     95,31%
